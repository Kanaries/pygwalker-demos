# %%
# import data
import pandas as pd

df = pd.read_csv("bike_sharing_dc.csv")

# %%
# explore data
import pygwalker as pyg

walker = pyg.walk(df, spec="first_explore.json")
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-0" style="height: auto">\n    <head>\n        <!-- ipywidgets.HTML …

# %%
walker.display_chart("Chart 1", title="First Explore", desc="This is my first attempt.")
# Out:
# <html>
# <body>
#     <div id="0-Chart 1" style="width: 100%; max-height: 600px;">
#
#         <h1 style="margin-top: 1rem; color: #333; font-size: 1.1rem; margin-bottom: 0.5rem; padding-inline-start: 1rem;">First Explore</h1>
#
#         <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;">This is my first attempt.</p>
#         <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#         <div class="main-box">
#
#             <div style="display: flex;">
#
#                 <img style="max-width: none;" height="248" width="411" src="data:image/png;base64,..." />
#
#             </div>
#
#         </div>
#     </div>
# </body>
# </html>

# %%
walker.display_chart("Chart 2", title="casual, registered, season")
# Out:
# <html>
# <body>
#     <div id="0-Chart 2" style="width: 100%; max-height: 600px;">
#
#         <h1 style="margin-top: 1rem; color: #333; font-size: 1.1rem; margin-bottom: 0.5rem; padding-inline-start: 1rem;">casual, registered, season</h1>
#
#         <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#         <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#         <div class="main-box">
#
#             <div style="display: flex;">
#
#                 <img style="max-width: none;" height="244" width="321" src="data:image/png;base64,..." />
#
#             </div>
#
#         </div>
#     </div>
# </body>
# </html>

# %%
walker.display_chart("Chart 3", title="casual, registered, working day")
# Out:
# <html>
# <body>
#     <div id="0-Chart 3" style="width: 100%; max-height: 600px;">
#
#         <h1 style="margin-top: 1rem; color: #333; font-size: 1.1rem; margin-bottom: 0.5rem; padding-inline-start: 1rem;">casual, registered, working day</h1>
#
#         <p style="color: #666; font-weight: 300; padding-inline-start: 1rem;"></p>
#         <!-- <p>Under certain Jupyter environments, after launching pygwalker, the preview may not automatically hide. You can manually click the button to hide it.</p> -->
#         <div class="main-box">
#
#             <div style="display: flex;">
#
#                 <img style="max-width: none;" height="244" width="350" src="data:image/png;base64,..." />
#
#             </div>
#
#         </div>
#     </div>
# </body>
# </html>
